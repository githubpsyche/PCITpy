% %% [markdown]
% ## Summary
% This notebook outlines the results of running analyze_outputs.m on the various data sets provided from Karina and Anne to me. Result file names are labeled by the data set used (e.g. angData_all, Karina's unsimulated data set), and then a three number code indicating, in order, 1) the number of iterations PCIT was ran on, 2) whether the DV was automatically z-scored by subject or not (1 if yes, 0 if no), and finally 3) whether the DV was z-scored overall or not. You should be able to use the guide below and the contents of the cell above a plot to understand to which data set the plots apply. Let me know if anything's unclear!
%
% ## Data Set Descriptions
% - **angData_all** - Karina's unsimulated data set
% - **simData_double_05_07_18** - Karina's simulated data set
% - **forJordan_mot5_BOLD_PS_ZX_noZY** - Anne's data w/ specs:
%      - BOLD = predictor variable is BOLD data (real-time classifier)
%      - PS = dependent variable is pattern similarity
%      - ZX = predictor variable is z-scored by subject
%      - noZY = dependent variable is NOT zscored
% - **forJordan_mot5_GLM_PS_ZX_noZY** - Anne's data w/ specs:
%      - GLM = predictor variable is GLM data (offline classifier)
%      - PS = dependent variable is pattern similarity
%      - ZX = predictor variable is z-scored by subject
%      - noZY = dependent variable is NOT zscored
% - **forJordan_mot5_BOLD_retrieval_ZX_noZY** - Anne's data w/ specs:
%      - BOLD = predictor variable is BOLD data (real-time classifier)
%      - retrieval = dependent variable is real-time retrieval evidence
%      - ZX = predictor variable is z-scored by subject
%      - noZY = dependent variable is NOT zscored
% - **forJordan_mot5_GLM_retrieval_ZX_noZY** - Anne's data w/ specs:
%      - GLM = predictor variable is GLM data (offline classifier)
%      - retrieval = dependent variable is real-time retrieval evidence
%      - ZX = predictor variable is z-scored by subject
%      - noZY = dependent variable is NOT zscored
% - Anne also produced versions of the above 4 data-sets using a simulated DV. The names for all of these are the same as above with _simulated meaning that for that particular matrix, everything is the same except the dependent variable (column 5).
%
% ## Outcomes
% There's not much point in trying to interpret anything other than the main Activation vs Change in Memory Strength curves produced from analyze_outputs.m, as the other plots have either different or no meaning under the PCIT modifications we've undertaken. We don't have any 20-iteration results yet because the first try at it was killed by spock's job manager for taking more than 10 hours to finish; I should be able to improve performance and split the job up in another try. With respect to our 1-iteration attempts, though, no U-shaped curves were inferred. I'm not sure what the "true" curves in the simulated instances were, so it's hard to judge how the 1-iteration modified PCIT did at inferring them until I have Anne/Karina's input. Will get 20-iteration results ASAP.

% %%
analyze_outputs('angData_all-1-0-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/angData_all-1-0-0/angData_all-1-0-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/angData_all-1-0-0/angData_all-1-0-0_report_plot.png

% %%
analyze_outputs('angData_all-1-0-1')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/angData_all-1-0-1/angData_all-1-0-1_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/angData_all-1-0-1/angData_all-1-0-1_report_plot.png

% %%
analyze_outputs('angData_all-1-1-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/angData_all-1-1-0/angData_all-1-1-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/angData_all-1-1-0/angData_all-1-1-0_report_plot.png

% %%
analyze_outputs('angData_all-1-1-1')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/angData_all-1-1-1/angData_all-1-1-1_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/angData_all-1-1-1/angData_all-1-1-1_report_plot.png

% %%
analyze_outputs('forJordan_mot5_BOLD_PS_ZX_noZY_simulated-1-0-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_BOLD_PS_ZX_noZY_simulated-1-0-0/forJordan_mot5_BOLD_PS_ZX_noZY_simulated-1-0-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_BOLD_PS_ZX_noZY_simulated-1-0-0/forJordan_mot5_BOLD_PS_ZX_noZY_simulated-1-0-0_report_plot.png

% %%
analyze_outputs('forJordan_mot5_BOLD_PS_ZX_noZY-1-0-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_BOLD_PS_ZX_noZY-1-0-0/forJordan_mot5_BOLD_PS_ZX_noZY-1-0-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_BOLD_PS_ZX_noZY-1-0-0/forJordan_mot5_BOLD_PS_ZX_noZY-1-0-0_report_plot.png

% %%
analyze_outputs('forJordan_mot5_BOLD_retrieval_ZX_noZY_simulated-1-0-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_BOLD_retrieval_ZX_noZY_simulated-1-0-0/forJordan_mot5_BOLD_retrieval_ZX_noZY_simulated-1-0-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_BOLD_retrieval_ZX_noZY_simulated-1-0-0/forJordan_mot5_BOLD_retrieval_ZX_noZY_simulated-1-0-0_report_plot.png

% %%
analyze_outputs('forJordan_mot5_BOLD_retrieval_ZX_noZY-1-0-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_BOLD_retrieval_ZX_noZY-1-0-0/forJordan_mot5_BOLD_retrieval_ZX_noZY-1-0-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_BOLD_retrieval_ZX_noZY-1-0-0/forJordan_mot5_BOLD_retrieval_ZX_noZY-1-0-0_report_plot.png

% %%
analyze_outputs('forJordan_mot5_GLM_PS_ZX_noZY-1-0-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_GLM_PS_ZX_noZY-1-0-0/forJordan_mot5_GLM_PS_ZX_noZY-1-0-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_GLM_PS_ZX_noZY-1-0-0/forJordan_mot5_GLM_PS_ZX_noZY-1-0-0_report_plot.png

% %%
analyze_outputs('forJordan_mot5_GLM_retrieval_ZX_noZY_simulated-1-0-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_GLM_retrieval_ZX_noZY_simulated-1-0-0/forJordan_mot5_GLM_retrieval_ZX_noZY_simulated-1-0-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_GLM_retrieval_ZX_noZY_simulated-1-0-0/forJordan_mot5_GLM_retrieval_ZX_noZY_simulated-1-0-0_report_plot.png

% %%
analyze_outputs('forJordan_mot5_GLM_retrieval_ZX_noZY-1-0-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_GLM_retrieval_ZX_noZY-1-0-0/forJordan_mot5_GLM_retrieval_ZX_noZY-1-0-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/forJordan_mot5_GLM_retrieval_ZX_noZY-1-0-0/forJordan_mot5_GLM_retrieval_ZX_noZY-1-0-0_report_plot.png

% %%
analyze_outputs('simData_double_05_07_18-1-0-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/simData_double_05_07_18-1-0-0/simData_double_05_07_18-1-0-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/simData_double_05_07_18-1-0-0/simData_double_05_07_18-1-0-0_report_plot.png

% %%
analyze_outputs('simData_double_05_07_18-1-0-1')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/simData_double_05_07_18-1-0-1/simData_double_05_07_18-1-0-1_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/simData_double_05_07_18-1-0-1/simData_double_05_07_18-1-0-1_report_plot.png

% %%
analyze_outputs('simData_double_05_07_18-1-1-0')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/simData_double_05_07_18-1-1-0/simData_double_05_07_18-1-1-0_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/simData_double_05_07_18-1-1-0/simData_double_05_07_18-1-1-0_report_plot.png

% %%
analyze_outputs('simData_double_05_07_18-1-1-1')
% Out:
% 1. Recovered curve plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/simData_double_05_07_18-1-1-1/simData_double_05_07_18-1-1-1_weighted_curve.png
% 2. Toolbox report plot is saved as /Users/jordangunn/Google Drive/pcit/p-cit-toolbox/results/simData_double_05_07_18-1-1-1/simData_double_05_07_18-1-1-1_report_plot.png
